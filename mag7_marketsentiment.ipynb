# %% [markdown]
# <a href="https://colab.research.google.com/github/eunicetcl/mag7vsSp500-datapipelines/blob/main/mag7_marketsentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/eunicetcl/mag7vsSp500-datapipelines
# Out:
# Cloning into 'mag7vsSp500-datapipelines'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 27 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 13.06 KiB | 6.53 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !pip install yfinance pandas
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)

# %%
import yfinance as yf
import pandas as pd

tickers = ["AAPL", "AMZN", "GOOG", "META", "MSFT", "NVDA", "TSLA"]

data = yf.download(tickers, interval="1d", auto_adjust=True, group_by="ticker")

# flatten to one DataFrame
rows = []
for t in tickers:
    df = data[t].reset_index()
    df["symbol"] = t
    rows.append(df)

prices = pd.concat(rows)
prices.head()
# Out:
# [*********************100%***********************]  7 of 7 completed
# Price       Date        Open        High         Low       Close    Volume  \
# 0     2025-11-04  268.070107  271.227050  267.360803  269.778473  49274800
# 1     2025-11-05  268.349840  271.436874  266.671474  269.878387  43683100
# 2     2025-11-06  267.630574  273.135217  267.630574  269.508728  51204000
# 3     2025-11-07  269.538690  272.026299  266.511626  268.209991  48227400
# 4     2025-11-10  268.959991  273.730011  267.459991  269.429993  41312400
#
# Price symbol
# 0       AAPL
# 1       AAPL
# 2       AAPL
# 3       AAPL
# 4       AAPL

# %%
prices.to_csv("mag7_prices.csv", index=False)

# %%
rows = []

for t in tickers:
    df = data[t].reset_index()
    df["symbol"] = t
    rows.append(df)

prices = pd.concat(rows).sort_values(["symbol", "Date"])
prices.head()
# Out:
# Price       Date        Open        High         Low       Close    Volume  \
# 0     2025-11-04  268.070107  271.227050  267.360803  269.778473  49274800
# 1     2025-11-05  268.349840  271.436874  266.671474  269.878387  43683100
# 2     2025-11-06  267.630574  273.135217  267.630574  269.508728  51204000
# 3     2025-11-07  269.538690  272.026299  266.511626  268.209991  48227400
# 4     2025-11-10  268.959991  273.730011  267.459991  269.429993  41312400
#
# Price symbol
# 0       AAPL
# 1       AAPL
# 2       AAPL
# 3       AAPL
# 4       AAPL

# %%
# !pip install pandas requests beautifulsoup4 --quiet

# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 3.2 MB/s eta 0:00:00
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=1bf5c70c44d0574bd2e817e59ef76e7f141c93e952f89b01fea944b0f32e7df1
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.12 sgmllib3k-1.0.0

# %%
import feedparser

rss_url = "https://feeds.finance.yahoo.com/rss/2.0/headline?s=AAPL&region=US&lang=en-US"
feed = feedparser.parse(rss_url)

yahoo_headlines = [entry.title for entry in feed.entries]
yahoo_headlines[:10]
# Out:
# ['Most popular stocks and funds investors bought in November',
#  "Coastal walks, castles and community: Britain's happiest places to live revealed",
#  'How to navigate an end-of-year performance review with minimal stress',
#  'Forget Intel Stock: You Should Buy This Unstoppable Tech Leader Instead',
#  "Apple, Nvidia, Verizon, IBM, & more: 2025's stock pick standouts",
#  'Walmart Stock Rallies, Pushing Market Cap Above $900 Billion',
#  "Apple's stock is hitting new highs: How to play it with options",
#  'Apple Design Executive Alan Dye Poached by Meta in Major Coup',
#  "AI bubble talk isn't constructive as trade is in 'early innings'",
#  'Apple iPhone 17 Sales Are Booming. Its Stock Is Hitting Record Highs Too.']

# %%
rss_url = "https://www.marketwatch.com/rss/topstories"

feed = feedparser.parse(rss_url)

mw_headlines = [entry.title for entry in feed.entries]

df_marketwatch = pd.DataFrame({
    "source": "MarketWatch",
    "headline": mw_headlines,
    "date": datetime.date.today()
})

df_marketwatch.head(10)
# Out:
#         source                                           headline        date
# 0  MarketWatch  Netflix and Paramount are now the favorites to...  2025-12-04
# 1  MarketWatch  Salesforce cheers ‘a powerful pipeline of futu...  2025-12-04
# 2  MarketWatch  Why Snowflake’s earnings beat isn’t enough to ...  2025-12-04
# 3  MarketWatch  Fiserv execs bet $1.5 million on a turnaround,...  2025-12-04
# 4  MarketWatch  As Marvell’s stock rises on an upbeat forecast...  2025-12-04
# 5  MarketWatch  AI needs power desperately. Here’s how to inve...  2025-12-04
# 6  MarketWatch  Microsoft’s stock falls on reported AI sales w...  2025-12-04
# 7  MarketWatch  Delta Air will see a hit because of shutdown’s...  2025-12-04
# 8  MarketWatch  Stock market closes on doorstep of record terr...  2025-12-04
# 9  MarketWatch  Trump touts rollback of fuel standards. Here’s...  2025-12-04

# %%
rss_cnbc = "https://www.cnbc.com/id/100003114/device/rss/rss.html"
feed_cnbc = feedparser.parse(rss_cnbc)

df_cnbc = pd.DataFrame({
    "source": "CNBC",
    "headline": [entry.title for entry in feed_cnbc.entries],
    "date": datetime.date.today()
})

df_cnbc.head(10)
# Out:
#   source                                           headline        date
# 0   CNBC  Salesforce beats on earnings, issues better-th...  2025-12-04
# 1   CNBC  Trump proposes slashing fuel efficiency standa...  2025-12-04
# 2   CNBC  Inside Europe’s biggest rare earths factory on...  2025-12-04
# 3   CNBC  Bank of Japan faces a policy dilemma as govern...  2025-12-04
# 4   CNBC  Design executive behind 'Liquid Glass' is leav...  2025-12-04
# 5   CNBC  Software startup deploys Singapore’s first qua...  2025-12-04
# 6   CNBC  Nvidia CEO Jensen Huang talks chip restriction...  2025-12-04
# 7   CNBC  A little-known startup just used AI to make a ...  2025-12-04
# 8   CNBC  Jeffrey Epstein island photos and videos relea...  2025-12-04
# 9   CNBC  Asia markets mostly rise after Wall Street gai...  2025-12-04

# %%
rss_investing = "https://www.investing.com/rss/news.rss"
feed_investing = feedparser.parse(rss_investing)

df_investing = pd.DataFrame({
    "source": "Investing.com",
    "headline": [entry.title for entry in feed_investing.entries],
    "date": datetime.date.today()
})

df_investing.head(10)
# Out:
#           source                                           headline  \
# 0  Investing.com  Exxon to permanently shut one steam cracker in...
# 1  Investing.com  Power Probe plans AIM listing, aims to raise $15m
# 2  Investing.com  European stocks push higher on elevated Fed cu...
# 3  Investing.com  Ofgem approves £28 billion investment to upgra...
# 4  Investing.com   How hedge funds performed in a volatile November
# 5  Investing.com  Watches of Switzerland lifts H1 earnings, tops...
# 6  Investing.com  New Earth Resources appoints geologist Cookenb...
# 7  Investing.com  JPMorgan reinstates Alfa Laval stock with Neut...
# 8  Investing.com  KKR completes acquisition of Spectris, CEO Hea...
# 9  Investing.com  Morgan Advanced Materials resets medium-term t...
#
#          date
# 0  2025-12-04
# 1  2025-12-04
# 2  2025-12-04
# 3  2025-12-04
# 4  2025-12-04
# 5  2025-12-04
# 6  2025-12-04
# 7  2025-12-04
# 8  2025-12-04
# 9  2025-12-04
